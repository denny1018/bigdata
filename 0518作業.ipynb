# %% [markdown]
# <a href="https://colab.research.google.com/github/denny1018/bigdata/blob/main/0518%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)
library(ggplot2)

# %%
NBA1718<-fetch_NBAPlayerStatistics("17-18")

# %%
NBA1718
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 1   NBA    Alex Abrines     OKL  SG       74          1134
# 2   NBA    Quincy Acy       BRO  SF       70          1361
# 3   NBA    Steven Adams     OKL  C        76          2486
# 4   NBA    Bam Adebayo      MIA  PF       69          1369
# 5   NBA    Arron Afflalo    ORL  SG       52           680
# 6   NBA    Cole Aldrich     MIN  C        21            51
# 7   NBA    Lamarcu Aldridge SAN  PF       75          2512
# 8   NBA    Jarrett Allen    BRO  C        72          1437
# 9   NBA    Kadeem Allen     BOS  SG       11           106
# 10  NBA    Tony Allen       NOR  SG       22           279
# 11  NBA    Al-farouq Aminu  POR  SF       69          2070
# 12  NBA    Justin Anderson  PHI  SG       38           519
# 13  NBA    Kyle Anderson    SAN  SG       74          1977
# 14  NBA    Ryan Anderson    HOU  PF       66          1727
# 15  NBA    Ike Anigbogu     IND  C        11            30
# ...

# %%
ggplot(NBA1718,aes(x=TotalMinutesPlayed,y=TotalPoints))+ geom_point()+geom_smooth(method = "glm")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
glm(TotalPoints~TotalMinutesPlayed+FieldGoalsAttempted+Position,
    data =NBA1718)
# Out:
# Call:  glm(formula = TotalPoints ~ TotalMinutesPlayed + FieldGoalsAttempted +
#     Position, data = NBA1718)
#
# Coefficients:
#         (Intercept)   TotalMinutesPlayed  FieldGoalsAttempted
#            29.02535             -0.01681              1.31181
#          PositionPF           PositionPG           PositionSF
#           -29.81577            -57.56647            -39.12716
#          PositionSG
#           -58.55942
#
# Degrees of Freedom: 538 Total (i.e. Null);  532 Residual
#   (1 observation deleted due to missingness)
# Null Deviance:	    117300000
# Residual Deviance: 1963000 	AIC: 5966

# %%
mydata <- read.csv("https://raw.githubusercontent.com/CGUIM-BigDataAnalysis/BigDataCGUIM/master/binary.csv")

# %%
head(mydata)
# Out:
#   admit gre gpa  rank
# 1 0     380 3.61 3
# 2 1     660 3.67 3
# 3 1     800 4.00 1
# 4 1     640 3.19 4
# 5 0     520 2.93 4
# 6 1     760 3.00 2

# %%
mydata$rank <-factor(mydata$rank)
mylogit <-glm(admit~gre+gpa+rank,data=mydata,family="binomial")
sum <-summary(mylogit)
sum $coefficients
# Out:
#             Estimate     Std. Error  z value   Pr(>|z|)
# (Intercept) -3.989979073 1.139950936 -3.500132 0.0004650273
# gre          0.002264426 0.001093998  2.069864 0.0384651284
# gpa          0.804037549 0.331819298  2.423119 0.0153878974
# rank2       -0.675442928 0.316489661 -2.134171 0.0328288188
# rank3       -1.340203916 0.345306418 -3.881202 0.0001039415
# rank4       -1.551463677 0.417831633 -3.713131 0.0002047107

# %%
install.packages("rpart")
library(rpart)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
DT <-rpart(Position~Blocks+ThreesMade+Assists+Steals,data=NBA1718)
DT
# Out:
# n=539 (1 observation deleted due to missingness)
#
# node), split, n, loss, yval, (yprob)
#       * denotes terminal node
#
#   1) root 539 398 SG (0.14 0.21 0.2 0.19 0.26)
#     2) Blocks>=36.5 108  68 C (0.37 0.29 0.037 0.23 0.074)
#       4) ThreesMade< 6 35   8 C (0.77 0.17 0 0.057 0) *
#       5) ThreesMade>=6 73  48 PF (0.18 0.34 0.055 0.32 0.11)
#        10) Assists< 159.5 40  19 PF (0.12 0.53 0 0.33 0.025)
#          20) Steals< 64 33  13 PF (0.15 0.61 0 0.21 0.03) *
#          21) Steals>=64 7   1 SF (0 0.14 0 0.86 0) *
#        11) Assists>=159.5 33  23 SF (0.24 0.12 0.12 0.3 0.21)
#          22) Blocks>=60.5 15   7 C (0.53 0.13 0.067 0.2 0.067) *
#          23) Blocks< 60.5 18  11 SF (0 0.11 0.17 0.39 0.33) *
#     3) Blocks< 36.5 431 298 SG (0.086 0.19 0.24 0.18 0.31)
#       6) Assists< 151.5 337 238 SG (0.11 0.23 0.16 0.21 0.29)
#        12) ThreesMade< 2.5 113  79 PF (0.27 0.3 0.13 0.13 0.17)
#          24) Blocks>=1.5 49  24 C (0.51 0.35 0.041 0.041 0.061) *
# ...

# %%
par(mfrow=c(1,1),mar=rep(1,4))
plot(DT)
text(DT,use.n=F,all=F,cex=1)
# Out:
# plot without title

# %%
install.packages("arules")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(arules)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘arules’
#
#
# The following objects are masked from ‘package:base’:
#
#     abbreviate, write

# %%
install.packages("datasets")
library(datasets)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘datasets’ is a base package, and should not be updated”

# %%
data(Groceries)

# %%
Groceries@data@Dim
# Out:
# [1]  169 9835

# %%
rules<-apriori(Groceries,parameter = list(supp=0.001,conf=0.8),control=list(verbose=F))

# %%
options(digits = 2)

# %%
inspect(rules[1:5])
# Out:
#     lhs                        rhs            support confidence coverage lift
# [1] {liquor,red/blush wine} => {bottled beer} 0.0019  0.90       0.0021   11.2
# [2] {curd,cereals}          => {whole milk}   0.0010  0.91       0.0011    3.6
# [3] {yogurt,cereals}        => {whole milk}   0.0017  0.81       0.0021    3.2
# [4] {butter,jam}            => {whole milk}   0.0010  0.83       0.0012    3.3
# [5] {soups,bottled beer}    => {whole milk}   0.0011  0.92       0.0012    3.6
#     count
# [1] 19
# [2] 10
# [3] 17
# [4] 10
# [5] 11

# %%
rules<-sort(rules, by="confidence", decreasing=TRUE) 
inspect(rules[1:5])
# Out:
#     lhs                     rhs          support confidence coverage lift count
# [1] {rice,
#      sugar}              => {whole milk}  0.0012          1   0.0012  3.9    12
# [2] {canned fish,
#      hygiene articles}   => {whole milk}  0.0011          1   0.0011  3.9    11
# [3] {root vegetables,
#      butter,
#      rice}               => {whole milk}  0.0010          1   0.0010  3.9    10
# [4] {root vegetables,
#      whipped/sour cream,
#      flour}              => {whole milk}  0.0017          1   0.0017  3.9    17
# [5] {butter,
#      soft cheese,
#      domestic eggs}      => {whole milk}  0.0010          1   0.0010  3.9    10

# %%
rulesR<-apriori(data=Groceries,parameter=list(supp=0.001,conf=0.08),appearance = list(default="lhs",rhs="whole milk"),control=list(verbose=F))
rulesR<-sort(rulesR,decreasing=TRUE,by="confidence")
inspect(rulesR[1:5])
# Out:
#     lhs                     rhs          support confidence coverage lift count
# [1] {rice,
#      sugar}              => {whole milk}  0.0012          1   0.0012  3.9    12
# [2] {canned fish,
#      hygiene articles}   => {whole milk}  0.0011          1   0.0011  3.9    11
# [3] {root vegetables,
#      butter,
#      rice}               => {whole milk}  0.0010          1   0.0010  3.9    10
# [4] {root vegetables,
#      whipped/sour cream,
#      flour}              => {whole milk}  0.0017          1   0.0017  3.9    17
# [5] {butter,
#      soft cheese,
#      domestic eggs}      => {whole milk}  0.0010          1   0.0010  3.9    10

# %%
rulesR<-apriori(data=Groceries,parameter=list(supp=0.001,conf=0.08),appearance = list(default="lhs",rhs="rice"),control=list(verbose=F))
rulesR<-sort(rulesR,decreasing=TRUE,by="confidence")
inspect(rulesR[1:5])
# Out:
#     lhs                        rhs    support confidence coverage lift count
# [1] {root vegetables,
#      other vegetables,
#      whole milk,
#      yogurt}                => {rice}  0.0013      0.169   0.0078   22    13
# [2] {root vegetables,
#      whole milk,
#      butter}                => {rice}  0.0010      0.123   0.0082   16    10
# [3] {root vegetables,
#      other vegetables,
#      yogurt}                => {rice}  0.0014      0.110   0.0129   14    14
# [4] {root vegetables,
#      whole milk,
#      yogurt}                => {rice}  0.0014      0.098   0.0145   13    14
# [5] {root vegetables,
#      fruit/vegetable juice} => {rice}  0.0011      0.093   0.0120   12    11

# %%
rulesL<-apriori(data=Groceries,parameter=list(supp=0.001,conf=0.15,minlen=2),appearance = list(default="rhs",lhs="whole milk"),control=list(verbose=F))
rulesL<-sort(rulesR,decreasing=TRUE,by="confidence")
inspect(rulesL[1:5])
# Out:
#     lhs                        rhs    support confidence coverage lift count
# [1] {root vegetables,
#      other vegetables,
#      whole milk,
#      yogurt}                => {rice}  0.0013      0.169   0.0078   22    13
# [2] {root vegetables,
#      whole milk,
#      butter}                => {rice}  0.0010      0.123   0.0082   16    10
# [3] {root vegetables,
#      other vegetables,
#      yogurt}                => {rice}  0.0014      0.110   0.0129   14    14
# [4] {root vegetables,
#      whole milk,
#      yogurt}                => {rice}  0.0014      0.098   0.0145   13    14
# [5] {root vegetables,
#      fruit/vegetable juice} => {rice}  0.0011      0.093   0.0120   12    11

# %%
rulesL<-apriori(data=Groceries,parameter=list(supp=0.001,conf=0.15,minlen=2),appearance = list(default="rhs",lhs="sugar"),control=list(verbose=F))
rulesL<-sort(rulesR,decreasing=TRUE,by="confidence")
inspect(rulesL[1:5])
# Out:
#     lhs                        rhs    support confidence coverage lift count
# [1] {root vegetables,
#      other vegetables,
#      whole milk,
#      yogurt}                => {rice}  0.0013      0.169   0.0078   22    13
# [2] {root vegetables,
#      whole milk,
#      butter}                => {rice}  0.0010      0.123   0.0082   16    10
# [3] {root vegetables,
#      other vegetables,
#      yogurt}                => {rice}  0.0014      0.110   0.0129   14    14
# [4] {root vegetables,
#      whole milk,
#      yogurt}                => {rice}  0.0014      0.098   0.0145   13    14
# [5] {root vegetables,
#      fruit/vegetable juice} => {rice}  0.0011      0.093   0.0120   12    11

# %%
rulesL<-apriori(data=Groceries,parameter=list(supp=0.001,conf=0.15,minlen=2),appearance = list(default="rhs",lhs="bottled beer"),control=list(verbose=F))
rulesL<-sort(rulesR,decreasing=TRUE,by="confidence")
inspect(rulesL[1:5])
# Out:
#     lhs                        rhs    support confidence coverage lift count
# [1] {root vegetables,
#      other vegetables,
#      whole milk,
#      yogurt}                => {rice}  0.0013      0.169   0.0078   22    13
# [2] {root vegetables,
#      whole milk,
#      butter}                => {rice}  0.0010      0.123   0.0082   16    10
# [3] {root vegetables,
#      other vegetables,
#      yogurt}                => {rice}  0.0014      0.110   0.0129   14    14
# [4] {root vegetables,
#      whole milk,
#      yogurt}                => {rice}  0.0014      0.098   0.0145   13    14
# [5] {root vegetables,
#      fruit/vegetable juice} => {rice}  0.0011      0.093   0.0120   12    11

# %%
NBA2021<-fetch_NBAPlayerStatistics("20-21")

# %%
NBA2021
# Out:
#     League Name            Team Position GamesPlayed TotalMinutesPlayed
# 1   NBA    Preciou Achiuwa MIA  PF       61           737
# 2   NBA    Jaylen Adams    MIL  PG        7            19
# 3   NBA    Steven Adams    NOR  C        58          1608
# 4   NBA    Bam Adebayo     MIA  PF       64          2141
# 5   NBA    Lamarc Aldridge BRO  PF       26           673
# 6   NBA    Ty-sh Alexander PHO  SG       15            46
# 7   NBA    Alexander-walke NOR  SG       46          1009
# 8   NBA    Grayson Allen   MEM  SG       50          1257
# 9   NBA    Jarrett Allen   CLE  C        63          1865
# 10  NBA    Al-farouq Aminu CHI  PF       23           433
# 11  NBA    Kyle Anderson   MEM  SF       69          1892
# 12  NBA    G Antetokounmpo MIL  PF       61          2011
# 13  NBA    K Antetokounmpo LAL  PF       15            56
# 14  NBA    T Antetokounmpo MIL  SF       57           555
# 15  NBA    Carmelo Anthony POR  PF       69          1689
# ...

# %%
ggplot(NBA2021,aes(x=TotalMinutesPlayed,y=TotalPoints))+ geom_point()+geom_smooth(method = "glm")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
glm(TotalPoints~TotalMinutesPlayed+FieldGoalsAttempted+Position,
    data =NBA1718)
# Out:
# Call:  glm(formula = TotalPoints ~ TotalMinutesPlayed + FieldGoalsAttempted +
#     Position, data = NBA1718)
#
# Coefficients:
#         (Intercept)   TotalMinutesPlayed  FieldGoalsAttempted
#             29.0253              -0.0168               1.3118
#          PositionPF           PositionPG           PositionSF
#            -29.8158             -57.5665             -39.1272
#          PositionSG
#            -58.5594
#
# Degrees of Freedom: 538 Total (i.e. Null);  532 Residual
#   (1 observation deleted due to missingness)
# Null Deviance:	    1.2e+08
# Residual Deviance: 2e+06 	AIC: 5970
